# %% [markdown]
# 1. Write a Python program to handle a ZeroDivisionError exception when dividing a number by zero.

# %%
try:
  s=10/0
except ZeroDivisionError:
  print("Can not divide by zero")
else:
  print(s)
finally:
  print('khatam')
# Out:
# Can not divide by zero
# khatam

# %% [markdown]
# 2. Write a Python program that prompts the user to input an integer and raises a ValueError exception if the input is not a valid integer.

# %%
try:
  a = int(input("Enter Input: "))

except ValueError:
  print("Enter appropriate int value")
# Out:
# Enter Input: a
# Enter appropriate int value

# %% [markdown]
# 3. Write a Python program that opens a file and handles a FileNotFoundError exception if the file does not exist.

# %%
try:
  with open('sample.text','r') as f:
    s=f.read()
except FileNotFoundError:
  print("File nahi mili")
# Out:
# File nahi mili

# %% [markdown]
# 4. Write a Python program that prompts the user to input two numbers and raises a TypeError exception if the inputs are not numerical.

# %%
a=input("Enter value: ")
b=input("Enter value: ")
x= float(a)
y= float(b)

if type(x) == float and type(y)==float:
  print(x+y)
else:
  raise TypeError("inputs are not numerical.")
# Out:
# Enter value: 2
# Enter value: s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7487/226520813.py in <cell line: 0>()
#       2 b=input("Enter value: ")
#       3 x= float(a)
# ----> 4 y= float(b)
#       5
#       6 if type(x) == float and type(y)==float:
#
# ValueError: could not convert string to float: 's'

# %% [markdown]
# 5. Write a Python program that opens a file and handles a PermissionError exception if there is a permission issue.

# %%
with open("/etc/hostsdfhsds", "w") as f:
      f.write("127.0.0.1 example.com")

# %%
# Raises PermissionError unless run with sudo/Administrator rights
with open("/etc/hosts", "a") as f:
    f.write("127.0.0.1 example.com")

# %%
# Raises PermissionError if 'config.ini' is marked as read-only in the OS
with open("config.ini", "w") as f:
    f.write("new_setting = True")

# %%
try:
    with open("restricted_file.txt", "w") as f:
        f.write("Hello")
except PermissionError:
    print("Error: You do not have permission to access this file.")

# %% [markdown]
# 6. Write a Python program that executes an operation on a list and handles an IndexError exception if the index is out of range.

# %%
try:
  l = ['a','b','c']
  l[3]
except IndexError:
  print("index is out of range")
# Out:
# index is out of range

# %% [markdown]
# 7. Write a Python program that executes division and handles an ArithmeticError exception if there is an arithmetic error.

# %%
try:
  a=float(input('enter first value'))
  b=float(input('enter second value'))
  print(a/b)
except ArithmeticError:
  print("Can not divide by zero")
finally:
  print('khatam')
# Out:
# enter first value2
# enter second value0
# Can not divide by zero
# khatam
